# %% [markdown]
#  1). Write a formula to check if the marks in cell B2 are greater than or equal to 40. If yes, return “Pass” , otherwise "Fail”.
#
#   Student Name  Makrs
#   Riya          45
#   Siya          72
#   Raju          55
#   Rahul         80
#   Ram           30
#
#
#
#             Answer :-  =IF(B5>=40,"pass","Fail")
#    ![Screenshot 2026-01-12 174509.png](data:image/png;base64,...)
#
#
#  2). A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not .
#
# Employee  Sales  Attendance
# Arjun     55000    95
# Simran    65000    85
# Rohit     30000    90
# Anjali    25000    65
#
#
#             Answer:-  =IF(AND(B3>40000,C3>=90),"Bonus","Not")
#
# ![Screenshot 2026-01-12 175915.png](data:image/png;base64,...)
#
# 3). Write a nested IF formula:  If marks in B2 are ≥ 90 → “A”, ≥ 75 → “B”, ≥ 50 → “C”, otherwise “Fail”.
#
# Student Name  Marks
# Raj            85
# Neha           96
# Vivek          57
# Rani           92
# Sneha          75
#
#
#
#           Answer:-  =IF(B3>90,"A",IF(B3>75,"B",IF(B3>50,"C","Fail")))
#
# ![Screenshot 2026-01-12 180801.png](data:image/png;base64,...)
#
# 4). Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# EmpID  Name  Department
# E101   Raju     IT
# E102   Riya     HR
# E103   Roshni  Finance
# E104   Sejal    Sales
#
#
#          Answer:-   =LOOKUP(F2,A2:C5)
# ![Screenshot 2026-01-12 182026.png](data:image/png;base64,...)
#
# * Employee ID is in the first column
#
# * We want to fetch data (Department) from the right side
#
#
# * Data is arranged vertically
#
#
# * Simple and commonly used for such tables
#
#  5). A company has set the following commission structure for its sales team:
#
# Sales Amount  Commission Rate
# 0                 5%
# 20000             10%
# 50000             15%
# 80000             20%
#
#   If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to            determine the commission rate applicable.
#
#
#          Answer:-    =VLOOKUP($E$3,$A$3:$B$6,2,1)
#
# ![Screenshot 2026-01-12 183232.png](data:image/png;base64,...)
#
#
#
# 6).The HR department maintains the following leave records of employees:onus or not .
#
#
# Employee Name  Leaves Taken  Leaves Allowed
# Alex              10             12
# Bob               10             15
# Anna              14             12
#
#
# Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#  * If Leaves Taken > Allowed Leaves, display "Exceeded".
# * Otherwise, display "OK".
#
#       Answer :-  =IF(B3>C3,"Eexceeded","ok")
#
# ![Screenshot 2026-01-12 183847.png](data:image/png;base64,...)
#
#
#
# 7). Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
#
# EmpID  Salary
# E104   55000
# E105   72000
# E106   62000
# E102   41000
#
#
#      Answer:-  =INDEX(B3:B6,  MATCH(E3,A3:A6,0))
#
# ![Screenshot 2026-01-12 184405.png](data:image/png;base64,...)
#
# 8). Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
#
# EmpID  Department
# E101     HR
# E303     IT
# E106   Sales
# E301  Finance
#
#
#       Answer:-  =XLOOKUP(E3,A3:A6,B3:B6,"not found")
#
# ![Screenshot 2026-01-12 184818.png](data:image/png;base64,...)
